# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import ipywidgets as widgets
from IPython.display import display

# %%
# Cargar el conjunto de datos
df_partidos = pd.read_csv("../partidos_cebollitas_fe82a1a4-e109-41b1-8b78-d9b4341dacaf.csv")
# df_partidos_cebollitas = df_partidos[(df_partidos['equipo_local'] == 'Cebollitas FC') | (df_partidos['equipo_visitante'] == 'Cebollitas FC')]
df_partidos_cebollitas = df_partidos[df_partidos['equipo_local'] == 'Cebollitas FC']
df_partidos_cebollitas.reset_index(drop=True, inplace=True)
df_partidos = df_partidos_cebollitas.copy()
df_partidos['diferencia_goles'] = df_partidos['goles_local'] - df_partidos['goles_visitante']
df_partidos['ratio_tiros_posesion_local'] = df_partidos['tiros_arco_local'] / (df_partidos['posesion_local (%)'])
df_partidos.head()
# Out:
#   fecha_partido   equipo_local equipo_visitante  goles_local  goles_visitante  \
# 0    2023-01-15  Cebollitas FC      Data United            1                0
# 1    2023-02-19  Cebollitas FC      Real Pandas            1                2
# 2    2023-03-19  Cebollitas FC      Data United            4                0
# 3    2023-05-21  Cebollitas FC      Real Pandas            0                1
# 4    2023-05-28  Cebollitas FC      Real Pandas            3                3
#
#    posesion_local (%)  posesion_visitante (%)  tiros_arco_local  \
# 0                  55                      45                10
# 1                  56                      44                 5
# 2                  49                      51                 4
# 3                  47                      53                11
# 4                  53                      47                 7
#
#    tiros_arco_visitante           estadio  diferencia_goles  \
# 0                     7      Python Arena                 1
# 1                     5        Estadio ML                -1
# 2                    12  Estadio DataCamp                 4
# 3                     5        Estadio ML                -1
# 4                     4      Python Arena                 0
#
#    ratio_tiros_posesion_local
# 0                    0.181818
# 1                    0.089286
# 2                    0.081633
# 3                    0.234043
# 4                    0.132075

# %%
# Slider interactivo para elegir porcentaje de  prueba
slider_test_size = widgets.FloatSlider(
    value=0.2,
    min=0.1,
    max=0.5,
    step=0.05,
    description='Tamaño prueba:',
    continuous_update=False
)

display(slider_test_size)
# Out:
# FloatSlider(value=0.2, continuous_update=False, description='Tamaño prueba:', max=0.5, min=0.1, step=0.05)

# %%
def dividir_datos(test_size):
    X = df_partidos[['posesion_local (%)', 'tiros_arco_local', 'goles_local']]
    y = df_partidos['diferencia_goles']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42)

    print(f"Tamaño del conjunto de entrenamiento: {len(X_train)} partidos")
    print(f"Tamaño del conjunto de prueba: {len(X_test)} partidos")

    return X_train, X_test, y_train, y_test

# Usa el widget interactivo
widgets.interactive(dividir_datos, test_size=slider_test_size)
# Out:
# interactive(children=(FloatSlider(value=0.15000000000000002, continuous_update=False, description='Tamaño prue…

# %%
# Division estandar recomendada 80% entrenamiento, 20% prueba
X_train, X_test, y_train, y_test = train_test_split(
    df_partidos[['posesion_local (%)', 'tiros_arco_local', 'goles_local']],
    df_partidos['diferencia_goles'],
    test_size=0.2,
    random_state=42
)

print("Conjunto de entrenamiento (primeros registros):")
display(X_train.head())

print("Conjunto de prueba (primeros registros):")
display(X_test.head())
# Out:
# Conjunto de entrenamiento (primeros registros):
#     posesion_local (%)  tiros_arco_local  goles_local
# 13                  42                10            5
# 1                   56                 5            1
# 23                  56                 4            5
# 5                   46                 3            1
# 2                   49                 4            4
# Conjunto de prueba (primeros registros):
#     posesion_local (%)  tiros_arco_local  goles_local
# 8                   57                11            2
# 16                  60                12            3
# 0                   55                10            1
# 24                  46                 5            3
# 11                  57                 7            5
